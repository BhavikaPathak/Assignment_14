# %% [markdown]
# # ANSWER 1
# MongoDB is a non-relational document database that provides support for JSON-like storage. The MongoDB database has a flexible data model that enables you to store unstructured data, and it provides full indexing support, and replication with rich and intuitive APIs.
#
# A non-relational database is a database that does not use the tabular schema of rows and columns found in most traditional database systems. Instead, non-relational databases use a storage model that is optimized for the specific requirements of the type of data being stored.
#
# MySQL is a mature relational database system, offering a familiar database environment for experienced IT professionals.
#
# MongoDB is a well-established, non-relational database system offering improved flexibility and horizontal scalability, but at the cost of some safety features of relational databases, such as referential integrity.

# %% [markdown]
# # ANSWER 2
# Features of MongoDB –
#
# Schema-less Database: It is the great feature provided by the MongoDB. A Schema-less database means one collection can hold different types of documents in it. Or in other words, in the MongoDB database, a single collection can hold multiple documents and these documents may consist of the different numbers of fields, content, and size. It is not necessary that the one document is similar to another document like in the relational databases. Due to this cool feature, MongoDB provides great flexibility to databases.
#
# Document Oriented: In MongoDB, all the data stored in the documents instead of tables like in RDBMS. In these documents, the data is stored in fields(key-value pair) instead of rows and columns which make the data much more flexible in comparison to RDBMS. And each document contains its unique object id.
#
# Indexing: In MongoDB database, every field in the documents is indexed with primary and secondary indices this makes easier and takes less time to get or search data from the pool of the data. If the data is not indexed, then database search each document with the specified query which takes lots of time and not so efficient.
#
# Scalability: MongoDB provides horizontal scalability with the help of sharding. Sharding means to distribute data on multiple servers, here a large amount of data is partitioned into data chunks using the shard key, and these data chunks are evenly distributed across shards that reside across many physical servers. It will also add new machines to a running database.
#
# Replication: MongoDB provides high availability and redundancy with the help of replication, it creates multiple copies of the data and sends these copies to a different server so that if one server fails, then the data is retrieved from another server.
#
# Aggregation: It allows to perform operations on the grouped data and get a single result or computed result. It is similar to the SQL GROUPBY clause. It provides three different aggregations i.e, aggregation pipeline, map-reduce function, and single-purpose aggregation methods
#
# High Performance: The performance of MongoDB is very high and data persistence as compared to another database due to its features like scalability, indexing, replication, etc.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#                                       ANSWER 3
import pymongo
client = pymongo.MongoClient("mongodb+srv://BhavikaPathak:bhavika@cluster0.xevimge.mongodb.net/?retryWrites=true&w=majority")
db = client.test
db
# Out:
# Database(MongoClient(host=['ac-tvyp0ut-shard-00-01.xevimge.mongodb.net:27017', 'ac-tvyp0ut-shard-00-02.xevimge.mongodb.net:27017', 'ac-tvyp0ut-shard-00-00.xevimge.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-lsu6hb-shard-0', tls=True), 'test')

# %%
#                                         ANSWER 3 CONTINUE 
db = client ['student_information']
data = [{"name":"a","class":"1","roll_no":"1"},
        {"name":"b","class":"1","roll_no":"2"},
        {"name":"c","class":"1","roll_no":"3"},
        {"name":"d","class":"1","roll_no":"4"},
        {"name":"e","class":"1","roll_no":"5"},
        {"name":"f","class":"1","roll_no":"6"},
        {"name":"g","class":"1","roll_no":"7"},
        {"name":"h","class":"1","roll_no":"8"},
        {"name":"i","class":"1","roll_no":"9"},
        {"name":"j","class":"1","roll_no":"10"}
]
coll_student_information= db["class_record"]
coll_student_information.insert_many(data)

# %%
#                                       ANSWER 4
db = client ['student_information']
data1 = {"name":"k","class":"1","roll_no":"11"}
coll_student_information= db["class_record"]
coll_student_information.insert_one(data1)
data2 = [{"email_id":"a1@gmail.com","address":"lmn"},
         {"email_id":"b2@gmail.com","address":"opq"},
         {"email_id":"c3@gmail.com","address":"rst"},
         {"email_id":"d4@gmail.com","address":"uvw"},
         {"email_id":"e5@gmail.com","address":"xyz"},
         {"email_id":"f6@gmail.com","address":"abc"},
         {"email_id":"g7@gmail.com","address":"dfe"},
         {"email_id":"h8@gmail.com","address":"ghi"},
         {"email_id":"i9@gmail.com","address":"jkl"},
         {"email_id":"j10@gmail.com","address":"mno"},
         {"email_id":"k11@gmail.com","address":"pqr"},
]
coll_student_information= db["class_record"]
coll_student_information.insert_many(data2)

# %%
#                                          ANSWER 4 CONTINUE
print("USE FIND_ONE METHOD")
coll_student_information.find_one()
# Out:
# USE FIND_ONE METHOD
# {'_id': ObjectId('63f627f295c1c2e37e4860a9'),
#  'name': 'g',
#  'class': '1',
#  'roll_no': '7'}

# %%
#                                          ANSWER 4 CONTINUE
print("USING THE METHOD OF FIND")
for i in coll_student_information.find():
    print(i)
# Out:
# USING THE METHOD OF FIND
# {'_id': ObjectId('63f627f295c1c2e37e4860a9'), 'name': 'g', 'class': '1', 'roll_no': '7'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a5'), 'name': 'c', 'class': '1', 'roll_no': '3'}
# {'_id': ObjectId('63f627f295c1c2e37e4860ac'), 'name': 'j', 'class': '1', 'roll_no': '10'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a3'), 'name': 'a', 'class': '1', 'roll_no': '1'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a6'), 'name': 'd', 'class': '1', 'roll_no': '4'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a4'), 'name': 'b', 'class': '1', 'roll_no': '2'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a7'), 'name': 'e', 'class': '1', 'roll_no': '5'}
# {'_id': ObjectId('63f627f295c1c2e37e4860aa'), 'name': 'h', 'class': '1', 'roll_no': '8'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a8'), 'name': 'f', 'class': '1', 'roll_no': '6'}
# {'_id': ObjectId('63f627f295c1c2e37e4860ab'), 'name': 'i', 'class': '1', 'roll_no': '9'}
# ...

# %%
#                                   ANSWER 5
#Find method in MongoDB Query is used to fetch a particular document from the MongoDB collection. There are totally six methods available in Mongo DB by which we can fetch particular records.
#Query – This is an optional parameter which defines the selection criteria. In simple words, what you want to search within a collection will be defined as a query.
#Syntax:
#find(query)
db = client ['student_information']
data3 = [{"name":"z","class":"1","roll_no":"1"},
         {"name":"y","class":"1","roll_no":"2"},
         {"name":"x","class":"1","roll_no":"3"},
         {"name":"w","class":"1","roll_no":"4"},
         {"name":"v","class":"1","roll_no":"5"},
         {"name":"u","class":"1","roll_no":"6"},
         {"name":"t","class":"1","roll_no":"7"},
         {"name":"s","class":"1","roll_no":"8"},
         {"name":"r","class":"1","roll_no":"9"},
         {"name":"q","class":"1","roll_no":"10"}
]
coll_student_information= db["class_record"]
coll_student_information.insert_many(data3)
for i in coll_student_information.find({"roll_no":{"$gte":'5'}}):
    print(i)
# Out:
# {'_id': ObjectId('63f627f295c1c2e37e4860a9'), 'name': 'g', 'class': '1', 'roll_no': '7'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a7'), 'name': 'e', 'class': '1', 'roll_no': '5'}
# {'_id': ObjectId('63f627f295c1c2e37e4860aa'), 'name': 'h', 'class': '1', 'roll_no': '8'}
# {'_id': ObjectId('63f627f295c1c2e37e4860a8'), 'name': 'f', 'class': '1', 'roll_no': '6'}
# {'_id': ObjectId('63f627f295c1c2e37e4860ab'), 'name': 'i', 'class': '1', 'roll_no': '9'}
# {'_id': ObjectId('63f62d336e06e7a6be0265a8'), 'name': 'h', 'class': '1', 'roll_no': '8'}
# {'_id': ObjectId('63f62d336e06e7a6be0265a9'), 'name': 'i', 'class': '1', 'roll_no': '9'}
# {'_id': ObjectId('63f62d336e06e7a6be0265a6'), 'name': 'f', 'class': '1', 'roll_no': '6'}
# {'_id': ObjectId('63f62d336e06e7a6be0265a5'), 'name': 'e', 'class': '1', 'roll_no': '5'}
# {'_id': ObjectId('63f62d336e06e7a6be0265a7'), 'name': 'g', 'class': '1', 'roll_no': '7'}
# ...

# %% [markdown]
# #                                         ANSWER 6
# The sort() method specifies the order in which the query returns the matching documents from the given collection. You must apply this method to the cursor before retrieving any documents from the database.

# %%
#                                       Answer 6 continue
db = client ['Age_Group']
data_age = [{"name":"lmn","age": 51},
         {"name":"opq","age": 9},
         {"name":"rst","age": 45},
         {"name":"uvw","age": 18},
         {"name":"xyz","age": 25}]
coll_family_information= db["family_record"]
coll_family_information.insert_many(data_age)
results = coll_family_information.find().sort("age", 1)

for i in results:
    print("age in Ascending order",i)
# Out:
# age in Ascending order {'_id': ObjectId('64b677e84cebed841d173e03'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b678214cebed841d173e08'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b678564cebed841d173e0d'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b678a94cebed841d173e33'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b678aa4cebed841d173e38'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b6790c4cebed841d173e47'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b6796b4cebed841d173e6d'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b6796c4cebed841d173e72'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b67a95bd1dff16a243da10'), 'name': 'opq', 'age': 9}
# age in Ascending order {'_id': ObjectId('64b677e84cebed841d173e05'), 'name': 'uvw', 'age': 18}
# ...

# %%
#                                       Answer 6 continue
db = client ['Age_Group']
data_age = [{"name":"lmn","age": 51},
         {"name":"opq","age": 9},
         {"name":"rst","age": 45},
         {"name":"uvw","age": 18},
         {"name":"xyz","age": 25}]
coll_family_information= db["family_record"]
coll_family_information.insert_many(data_age)
results = coll_family_information.find().sort("age", -1)

for i in results:
    print("age in desending order",i)
# Out:
# age in desending order {'_id': ObjectId('64b677e84cebed841d173e02'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b678214cebed841d173e07'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b678564cebed841d173e0c'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b678a94cebed841d173e32'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b678aa4cebed841d173e37'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b6790c4cebed841d173e46'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b6796b4cebed841d173e6c'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b6796c4cebed841d173e71'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b67a95bd1dff16a243da0f'), 'name': 'lmn', 'age': 51}
# age in desending order {'_id': ObjectId('64b67accbd1dff16a243da14'), 'name': 'lmn', 'age': 51}
# ...

# %% [markdown]
# #                                       ANSWER 7
# Delete_many() is used when one needs to delete more than one document. A query object containing which document to be deleted is created and is passed as the first parameter to the delete_many().
# #In MongoDB, a single document can be deleted by the method delete_one(). The first parameter of the method would be a query object which defines the document to be deleted.
# #Use of Drop Collection in MongoDB:
# #To remove a collection completely, use the db.collection.drop() method and drop the entire collection, including the indexes and then reuse the collection. A user can recreate the collection and rebuild the indexes following the removal. The approach helps avoid flushing the cache
